# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (1.38.0)
# Requirement already satisfied: altair<6,>=4.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (2.32.2)
# Requirement already satisfied: rich<14,>=10.14.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: jinja2 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import json
import os
import random

DATA_FILE = "swedish_words.json"
GROUPS = ["0%", "25%", "50%", "100%"]

# Load or initialize
def load_words():
    if not os.path.exists(DATA_FILE):
        return []
    with open(DATA_FILE, "r", encoding="utf-8") as f:
        return json.load(f)

def save_words(words):
    with open(DATA_FILE, "w", encoding="utf-8") as f:
        json.dump(words, f, indent=2, ensure_ascii=False)

def add_word(swedish, english, category):
    words = load_words()
    words.append({
        "swedish": swedish,
        "english": english,
        "group": "0%",
        "category": category
    })
    save_words(words)

def update_word_group(word, correct):
    idx = GROUPS.index(word["group"])
    if correct and idx < len(GROUPS) - 1:
        word["group"] = GROUPS[idx + 1]
    elif not correct and idx > 0:
        word["group"] = GROUPS[idx - 1]

def select_random_mixture(words):
    result = []
    ratios = {"0%": 0.6, "25%": 0.2, "50%": 0.15, "100%": 0.05}
    for group, ratio in ratios.items():
        gw = [w for w in words if w["group"] == group]
        count = max(1, int(len(words) * ratio))
        result.extend(random.sample(gw, min(len(gw), count)))
    random.shuffle(result)
    return result

def main():
    st.title("📘 Swedish Flashcard App")

    menu = st.sidebar.selectbox("Choose action", ["Add New Word", "Training Session"])

    if menu == "Add New Word":
        st.header("➕ Add a New Word")
        swedish = st.text_input("Swedish Word")
        english = st.text_input("English Meaning")
        category = st.text_input("Category (e.g., at home, in the office)")
        if st.button("Add Word"):
            if swedish and english and category:
                add_word(swedish, english, category)
                st.success(f"Added '{swedish}' successfully!")
            else:
                st.warning("Please fill all fields.")

    elif menu == "Training Session":
        st.header("🧠 Training")
        words = load_words()
        group_option = st.selectbox("Select Group", ["0%", "25%", "50%", "100%", "random"])

        if group_option == "random":
            session_words = select_random_mixture(words)
        else:
            session_words = [w for w in words if w["group"] == group_option]

        if "index" not in st.session_state:
            st.session_state.index = 0
            st.session_state.answers = []

        if session_words:
            if st.session_state.index < len(session_words):
                word = session_words[st.session_state.index]
                st.subheader(f"Swedish Word: **{word['swedish']}**")
                answer = st.text_input("What is the English meaning?", key=f"ans_{st.session_state.index}")

                col1, col2 = st.columns(2)
                if col1.button("✅ Correct"):
                    update_word_group(word, True)
                    st.session_state.index += 1
                    save_words(words)
                if col2.button("❌ Incorrect"):
                    update_word_group(word, False)
                    st.session_state.index += 1
                    save_words(words)
            else:
                st.success("🎉 Training complete!")
                if st.button("Start Over"):
                    st.session_state.index = 0
        else:
            st.warning("No words available in this group.")

if __name__ == "__main__":
    main()
# Out:
# 2025-06-13 17:31:45.291 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.353
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Volumes/Anaconda/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-06-13 17:31:45.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.355 Session state does not function when running a script without `streamlit run`
# 2025-06-13 17:31:45.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-13 17:31:45.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
